# %%
# %cd ../
# Out:
# /home/ubuntu/ganomaly

# %%
# !python test.py --dataset cifar10 --isize 32 --niter 15 --abnormal_class car --manualseed 1
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# OrderedDict([('Avg Run Time (ms/batch)', 11.65306568145752), ('roc', 0.5246261959876544)])

# %%
# PDFを出すため
# !pip install latex
# Out:
# ...
# Processing /home/ubuntu/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94/future-0.18.2-py3-none-any.whl
# ...
#   Created wheel for latex: filename=latex-0.7.0-py3-none-any.whl size=7605 sha256=7fbb178d07fd4cd9aba71bec4d3fcdc08883f5374899a93200124f793000ed6e
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/6f/1a/6d/d4ced668b03b4f00c5f75901a70e2c174063c435971de2468a
# ...
#   Created wheel for tempdir: filename=tempdir-0.7.1-py3-none-any.whl size=2213 sha256=09985e7fa196ed3878ba55bc5d3aceee3d4c975601c1db2ff981b1e25bdf30ac
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/41/c2/dd/9bb5b61c645d38b61a8c75ae52f4f259982f7cf3e89499a3db
# ...
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7246 sha256=71285bcf288fe744c0f568e2b8a899e4f38d537218bc7fcecf8016dfda895414
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/eb/ea/70/7e6f6faa3b2486d1ff468f52df9cfb0718c307774f538fe3b8
# ...

# %%
# https://stackoverflow.com/questions/58121461/runtimeerror-failed-to-process-string-with-tex-because-latex-could-not-be-found
# PDF出力ができなかったため
# !sudo apt install texlive texlive-latex-extra texlive-fonts-recommended dvipng -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-lato fonts-lmodern fonts-texgyre javascript-common
#   libapache-pom-java libauthen-sasl-perl libcommons-logging-java
#   libcommons-parent-java libdata-dump-perl libencode-locale-perl
#   libfile-basedir-perl libfile-desktopentry-perl libfile-listing-perl
#   libfile-mimeinfo-perl libfont-afm-perl libfontbox-java libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
#   libhtml-tree-perl libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl libio-stringy-perl libipc-system-simple-perl
#   libjs-jquery libkpathsea6 liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-dbus-perl libnet-http-perl libnet-smtp-ssl-perl
# ...
